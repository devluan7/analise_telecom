# %%
import pandas as pd

# %%
df_telecom = pd.read_csv("../database/clientes_telecom.csv")

# %%
#Vendo se tem dados vazio
df_telecom.isnull().sum()
# Out:
# id_cliente                      0
# genero                          0
# idoso                           0
# tem_parceiro                    0
# tem_dependentes                 0
# meses_na_empresa                0
# servico_telefone                0
# multiplas_linhas                0
# servico_internet                0
# servico_seguranca               0
# servico_backup                  0
# servico_protecao_equipamento    0
# servico_suporte_tecnico         0
# streaming_tv                    0
# streaming_filmes                0
# contrato                        0
# fatura_digital                  0
# forma_pagamento                 0
# valor_mensal                    0
# total_gasto                     0
# churn                           0
# dtype: int64

# %%
#Vendo as informações de cada coluna
df_telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_cliente                    7043 non-null   object
#  1   genero                        7043 non-null   object
#  2   idoso                         7043 non-null   object
#  3   tem_parceiro                  7043 non-null   object
#  4   tem_dependentes               7043 non-null   object
#  5   meses_na_empresa              7043 non-null   int64
#  6   servico_telefone              7043 non-null   object
#  7   multiplas_linhas              7043 non-null   object
#  8   servico_internet              7043 non-null   object
#  9   servico_seguranca             7043 non-null   object
#  10  servico_backup                7043 non-null   object
#  11  servico_protecao_equipamento  7043 non-null   object
# ...

# %%
#Resumo de estátisticas do df
df_telecom.describe()
# Out:
#        meses_na_empresa  valor_mensal  total_gasto
# count       7043.000000   7043.000000  7043.000000
# mean          32.371149     64.761692  2281.916928
# std           24.559481     30.090047  2265.270398
# min            0.000000     18.250000    18.800000
# 25%            9.000000     35.500000   402.225000
# 50%           29.000000     70.350000  1397.475000
# 75%           55.000000     89.850000  3786.600000
# max           72.000000    118.750000  8684.800000

# %%
#5 primeiras linhas do df
df_telecom.head()
# Out:
#    id_cliente     genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0  7590-VHVEG   Feminino   Não          Sim             Não                 1
# 1  5575-GNVDE  Masculino   Não          Não             Não                34
# 2  3668-QPYBK  Masculino   Não          Não             Não                 2
# 3  7795-CFOCW  Masculino   Não          Não             Não                45
# 4  9237-HQITU   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  ...  \
# 0              Não              Não              DSL               Não  ...
# 1              Sim              Não              DSL               Sim  ...
# 2              Sim              Não              DSL               Sim  ...
# 3              Não              Não              DSL               Sim  ...
# 4              Sim              Não     Fibra optica               Não  ...
#
# ...
